# %%
# !pip install -r requirements.txt

# %%
# !pip install PyWavelets
# Out:
# Requirement already satisfied: PyWavelets in c:\users\dell\anaconda3\envs\anaconda\lib\site-packages (1.4.1)
# Requirement already satisfied: numpy>=1.17.3 in c:\users\dell\anaconda3\envs\anaconda\lib\site-packages (from PyWavelets) (1.24.4)

# %%
# !pip install opencv-python==4.8.1.78

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./images_dataset/maria_sharapova/95349717081091468_hv3jryev_f.jpg')
img.shape
# Out:
# (877, 584, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (877, 584)

# %%
gray
# Out:
# array([[22, 16,  8, ...,  9, 12, 13],
#        [23, 16,  8, ..., 10, 12, 13],
#        [23, 17,  9, ..., 10, 12, 13],
#        ...,
#        [35, 37, 40, ..., 19,  7,  4],
#        [36, 37, 40, ..., 51, 20,  5],
#        [36, 36, 39, ..., 86, 52, 34]], dtype=uint8)

# %%
plt.imshow(gray,cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('./haarcascades/haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('./haarcascades/haarcascade_eye.xml')
faces = face_cascade.detectMultiScale(gray,1.3,5)
faces
# Out:
# array([[162,  92, 273, 273]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (162, 92, 273, 273)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
plt.imshow(roi_color, cmap='gray')

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.3, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./images_dataset/maria_sharapova/95349717081091468_hv3jryev_f.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./images_dataset/maria_sharapova/95349717081091468_hv3jryev_f.jpg')
plt.imshow(cropped_image)

# %%
org_image_obstructed = cv2.imread('./images_dataset/maria_sharapova/3-681.jpg')
plt.imshow(org_image_obstructed)

# %%
path_to_data = "./images_dataset/"
path_to_cr_data = "./cropped_image/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./images_dataset/lionel_messi',
#  './images_dataset/maria_sharapova',
#  './images_dataset/roger_federer',
#  './images_dataset/serena_williams',
#  './images_dataset/virat_kohli']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    print(celebrity_name)
    celebrity_file_names_dict[celebrity_name] = []
    
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
                
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name 
            
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# lionel_messi
# Generating cropped images in folder:  ./cropped_image/lionel_messi
# maria_sharapova
# Generating cropped images in folder:  ./cropped_image/maria_sharapova
# roger_federer
# Generating cropped images in folder:  ./cropped_image/roger_federer
# serena_williams
# Generating cropped images in folder:  ./cropped_image/serena_williams
# virat_kohli
# Generating cropped images in folder:  ./cropped_image/virat_kohli

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)

    return imArray_H

# %%
im_har = w2d(cropped_image,'db1',5)
plt.imshow(im_har,cmap='gray')

# %%
celebrity_file_names_dict
# Out:
# {'lionel_messi': ['./cropped_image/lionel_messi/lionel_messi1.png',
#   './cropped_image/lionel_messi/lionel_messi2.png',
#   './cropped_image/lionel_messi/lionel_messi3.png',
#   './cropped_image/lionel_messi/lionel_messi4.png',
#   './cropped_image/lionel_messi/lionel_messi5.png',
#   './cropped_image/lionel_messi/lionel_messi6.png',
#   './cropped_image/lionel_messi/lionel_messi7.png',
#   './cropped_image/lionel_messi/lionel_messi8.png',
#   './cropped_image/lionel_messi/lionel_messi9.png',
#   './cropped_image/lionel_messi/lionel_messi10.png',
#   './cropped_image/lionel_messi/lionel_messi11.png',
#   './cropped_image/lionel_messi/lionel_messi12.png',
#   './cropped_image/lionel_messi/lionel_messi13.png',
#   './cropped_image/lionel_messi/lionel_messi14.png',
#   './cropped_image/lionel_messi/lionel_messi15.png',
#   './cropped_image/lionel_messi/lionel_messi16.png',
#   './cropped_image/lionel_messi/lionel_messi17.png',
#   './cropped_image/lionel_messi/lionel_messi18.png',
#   './cropped_image/lionel_messi/lionel_messi19.png',
#   './cropped_image/lionel_messi/lionel_messi20.png',
#   './cropped_image/lionel_messi/lionel_messi21.png',
#   './cropped_image/lionel_messi/lionel_messi22.png',
#   './cropped_image/lionel_messi/lionel_messi23.png',
#   './cropped_image/lionel_messi/lionel_messi24.png',
#   './cropped_image/lionel_messi/lionel_messi25.png',
#   './cropped_image/lionel_messi/lionel_messi26.png',
#   './cropped_image/lionel_messi/lionel_messi27.png',
#   './cropped_image/lionel_messi/lionel_messi28.png',
#   './cropped_image/lionel_messi/lionel_messi29.png',
#   './cropped_image/lionel_messi/lionel_messi30.png',
#   './cropped_image/lionel_messi/lionel_messi31.png',
#   './cropped_image/lionel_messi/lionel_messi32.png',
#   './cropped_image/lionel_messi/lionel_messi33.png',
#   './cropped_image/lionel_messi/lionel_messi34.png',
#   './cropped_image/lionel_messi/lionel_messi35.png',
#   './cropped_image/lionel_messi/lionel_messi36.png',
#   './cropped_image/lionel_messi/lionel_messi37.png',
#   './cropped_image/lionel_messi/lionel_messi38.png',
#   './cropped_image/lionel_messi/lionel_messi39.png'],
#  'maria_sharapova': ['./cropped_image/maria_sharapova/maria_sharapova1.png',
#   './cropped_image/maria_sharapova/maria_sharapova2.png',
#   './cropped_image/maria_sharapova/maria_sharapova3.png',
#   './cropped_image/maria_sharapova/maria_sharapova4.png',
#   './cropped_image/maria_sharapova/maria_sharapova5.png',
#   './cropped_image/maria_sharapova/maria_sharapova6.png',
#   './cropped_image/maria_sharapova/maria_sharapova7.png',
#   './cropped_image/maria_sharapova/maria_sharapova8.png',
#   './cropped_image/maria_sharapova/maria_sharapova9.png',
#   './cropped_image/maria_sharapova/maria_sharapova10.png',
#   './cropped_image/maria_sharapova/maria_sharapova11.png',
#   './cropped_image/maria_sharapova/maria_sharapova12.png',
#   './cropped_image/maria_sharapova/maria_sharapova13.png',
#   './cropped_image/maria_sharapova/maria_sharapova14.png',
#   './cropped_image/maria_sharapova/maria_sharapova15.png',
#   './cropped_image/maria_sharapova/maria_sharapova16.png',
#   './cropped_image/maria_sharapova/maria_sharapova17.png',
#   './cropped_image/maria_sharapova/maria_sharapova18.png',
#   './cropped_image/maria_sharapova/maria_sharapova19.png',
#   './cropped_image/maria_sharapova/maria_sharapova20.png',
#   './cropped_image/maria_sharapova/maria_sharapova21.png',
#   './cropped_image/maria_sharapova/maria_sharapova22.png',
#   './cropped_image/maria_sharapova/maria_sharapova23.png',
#   './cropped_image/maria_sharapova/maria_sharapova24.png',
#   './cropped_image/maria_sharapova/maria_sharapova25.png',
#   './cropped_image/maria_sharapova/maria_sharapova26.png',
#   './cropped_image/maria_sharapova/maria_sharapova27.png',
#   './cropped_image/maria_sharapova/maria_sharapova28.png',
#   './cropped_image/maria_sharapova/maria_sharapova29.png',
#   './cropped_image/maria_sharapova/maria_sharapova30.png',
#   './cropped_image/maria_sharapova/maria_sharapova31.png',
#   './cropped_image/maria_sharapova/maria_sharapova32.png',
#   './cropped_image/maria_sharapova/maria_sharapova33.png',
#   './cropped_image/maria_sharapova/maria_sharapova34.png',
#   './cropped_image/maria_sharapova/maria_sharapova35.png'],
#  'roger_federer': ['./cropped_image/roger_federer/roger_federer1.png',
#   './cropped_image/roger_federer/roger_federer2.png',
#   './cropped_image/roger_federer/roger_federer3.png',
#   './cropped_image/roger_federer/roger_federer4.png',
#   './cropped_image/roger_federer/roger_federer5.png',
#   './cropped_image/roger_federer/roger_federer6.png',
#   './cropped_image/roger_federer/roger_federer7.png',
#   './cropped_image/roger_federer/roger_federer8.png',
#   './cropped_image/roger_federer/roger_federer9.png',
#   './cropped_image/roger_federer/roger_federer10.png',
#   './cropped_image/roger_federer/roger_federer11.png',
#   './cropped_image/roger_federer/roger_federer12.png',
#   './cropped_image/roger_federer/roger_federer13.png',
#   './cropped_image/roger_federer/roger_federer14.png',
#   './cropped_image/roger_federer/roger_federer15.png',
#   './cropped_image/roger_federer/roger_federer16.png',
#   './cropped_image/roger_federer/roger_federer17.png',
#   './cropped_image/roger_federer/roger_federer18.png',
#   './cropped_image/roger_federer/roger_federer19.png',
#   './cropped_image/roger_federer/roger_federer20.png',
#   './cropped_image/roger_federer/roger_federer21.png',
#   './cropped_image/roger_federer/roger_federer22.png',
#   './cropped_image/roger_federer/roger_federer23.png',
#   './cropped_image/roger_federer/roger_federer24.png',
#   './cropped_image/roger_federer/roger_federer25.png',
#   './cropped_image/roger_federer/roger_federer26.png',
#   './cropped_image/roger_federer/roger_federer27.png',
#   './cropped_image/roger_federer/roger_federer28.png',
#   './cropped_image/roger_federer/roger_federer29.png',
#   './cropped_image/roger_federer/roger_federer30.png'],
#  'serena_williams': ['./cropped_image/serena_williams/serena_williams1.png',
#   './cropped_image/serena_williams/serena_williams2.png',
#   './cropped_image/serena_williams/serena_williams3.png',
#   './cropped_image/serena_williams/serena_williams4.png',
#   './cropped_image/serena_williams/serena_williams5.png',
#   './cropped_image/serena_williams/serena_williams6.png',
#   './cropped_image/serena_williams/serena_williams7.png',
#   './cropped_image/serena_williams/serena_williams8.png',
#   './cropped_image/serena_williams/serena_williams9.png',
#   './cropped_image/serena_williams/serena_williams10.png',
#   './cropped_image/serena_williams/serena_williams11.png',
#   './cropped_image/serena_williams/serena_williams12.png',
#   './cropped_image/serena_williams/serena_williams13.png',
#   './cropped_image/serena_williams/serena_williams14.png',
#   './cropped_image/serena_williams/serena_williams15.png',
#   './cropped_image/serena_williams/serena_williams16.png',
#   './cropped_image/serena_williams/serena_williams17.png',
#   './cropped_image/serena_williams/serena_williams18.png',
#   './cropped_image/serena_williams/serena_williams19.png',
#   './cropped_image/serena_williams/serena_williams20.png',
#   './cropped_image/serena_williams/serena_williams21.png',
#   './cropped_image/serena_williams/serena_williams22.png',
#   './cropped_image/serena_williams/serena_williams23.png',
#   './cropped_image/serena_williams/serena_williams24.png',
#   './cropped_image/serena_williams/serena_williams25.png',
#   './cropped_image/serena_williams/serena_williams26.png',
#   './cropped_image/serena_williams/serena_williams27.png',
#   './cropped_image/serena_williams/serena_williams28.png',
#   './cropped_image/serena_williams/serena_williams29.png',
#   './cropped_image/serena_williams/serena_williams30.png',
#   './cropped_image/serena_williams/serena_williams31.png',
#   './cropped_image/serena_williams/serena_williams32.png',
#   './cropped_image/serena_williams/serena_williams33.png',
#   './cropped_image/serena_williams/serena_williams34.png',
#   './cropped_image/serena_williams/serena_williams35.png'],
#  'virat_kohli': ['./cropped_image/virat_kohli/virat_kohli1.png',
#   './cropped_image/virat_kohli/virat_kohli2.png',
#   './cropped_image/virat_kohli/virat_kohli3.png',
#   './cropped_image/virat_kohli/virat_kohli4.png',
#   './cropped_image/virat_kohli/virat_kohli5.png',
#   './cropped_image/virat_kohli/virat_kohli6.png',
#   './cropped_image/virat_kohli/virat_kohli7.png',
#   './cropped_image/virat_kohli/virat_kohli8.png',
#   './cropped_image/virat_kohli/virat_kohli9.png',
#   './cropped_image/virat_kohli/virat_kohli10.png',
#   './cropped_image/virat_kohli/virat_kohli11.png',
#   './cropped_image/virat_kohli/virat_kohli12.png',
#   './cropped_image/virat_kohli/virat_kohli13.png',
#   './cropped_image/virat_kohli/virat_kohli14.png',
#   './cropped_image/virat_kohli/virat_kohli15.png',
#   './cropped_image/virat_kohli/virat_kohli16.png',
#   './cropped_image/virat_kohli/virat_kohli17.png',
#   './cropped_image/virat_kohli/virat_kohli18.png',
#   './cropped_image/virat_kohli/virat_kohli19.png',
#   './cropped_image/virat_kohli/virat_kohli20.png',
#   './cropped_image/virat_kohli/virat_kohli21.png',
#   './cropped_image/virat_kohli/virat_kohli22.png',
#   './cropped_image/virat_kohli/virat_kohli23.png',
#   './cropped_image/virat_kohli/virat_kohli24.png',
#   './cropped_image/virat_kohli/virat_kohli25.png',
#   './cropped_image/virat_kohli/virat_kohli26.png',
#   './cropped_image/virat_kohli/virat_kohli27.png',
#   './cropped_image/virat_kohli/virat_kohli28.png',
#   './cropped_image/virat_kohli/virat_kohli29.png',
#   './cropped_image/virat_kohli/virat_kohli30.png',
#   './cropped_image/virat_kohli/virat_kohli31.png',
#   './cropped_image/virat_kohli/virat_kohli32.png',
#   './cropped_image/virat_kohli/virat_kohli33.png',
#   './cropped_image/virat_kohli/virat_kohli34.png',
#   './cropped_image/virat_kohli/virat_kohli35.png',
#   './cropped_image/virat_kohli/virat_kohli36.png',
#   './cropped_image/virat_kohli/virat_kohli37.png',
#   './cropped_image/virat_kohli/virat_kohli38.png',
#   './cropped_image/virat_kohli/virat_kohli39.png',
#   './cropped_image/virat_kohli/virat_kohli40.png',
#   './cropped_image/virat_kohli/virat_kohli41.png',
#   './cropped_image/virat_kohli/virat_kohli42.png',
#   './cropped_image/virat_kohli/virat_kohli43.png',
#   './cropped_image/virat_kohli/virat_kohli44.png',
#   './cropped_image/virat_kohli/virat_kohli45.png',
#   './cropped_image/virat_kohli/virat_kohli46.png',
#   './cropped_image/virat_kohli/virat_kohli47.png',
#   './cropped_image/virat_kohli/virat_kohli48.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'lionel_messi': 0,
#  'maria_sharapova': 1,
#  'roger_federer': 2,
#  'serena_williams': 3,
#  'virat_kohli': 4}

# %%
X = []
y = []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        if img is None:
            continue
        scalled_raw_img = cv2.resize(img,(32,32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har,(32,32))
        combined_img=np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
len(X[0])
# Out:
# 4096

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (166, 4096)

# %% [markdown]
# # Data Cleaning Completed
#
# # Model training

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report

# %%
X_train,X_test,y_train,y_test =  train_test_split(X,y,random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.8809523809523809

# %%
print(classification_report(y_test,pipe.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      0.71      0.83         7
#            1       1.00      0.78      0.88         9
#            2       0.57      1.00      0.73         4
#            3       0.89      1.00      0.94         8
#            4       0.93      0.93      0.93        14
#
#     accuracy                           0.88        42
#    macro avg       0.88      0.88      0.86        42
# weighted avg       0.91      0.88      0.88        42

# %% [markdown]
# ### Grid Search

# %%
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV

# %%
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
            'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
        }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}

# %%
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.838333
# 1        random_forest    0.669667
# 2  logistic_regression    0.806333
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators
# Out:
# {'svm': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('svc',
#                   SVC(C=1, gamma='auto', kernel='linear', probability=True))]),
#  'random_forest': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('randomforestclassifier',
#                   RandomForestClassifier(n_estimators=10))]),
#  'logistic_regression': Pipeline(steps=[('standardscaler', StandardScaler()),
#                  ('logisticregression',
#                   LogisticRegression(C=1, solver='liblinear'))])}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.8571428571428571

# %%
best_estimators['random_forest'].score(X_test,y_test)
# Out:
# 0.5714285714285714

# %%
best_estimators['logistic_regression'].score(X_test,y_test)
# Out:
# 0.8333333333333334

# %%
best_clf = best_estimators['svm']

# %%
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 5,  0,  0,  2,  0],
#        [ 0,  8,  0,  1,  0],
#        [ 0,  1,  2,  1,  0],
#        [ 0,  0,  0,  8,  0],
#        [ 0,  0,  1,  0, 13]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(95.72222222222221, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'lionel_messi': 0,
#  'maria_sharapova': 1,
#  'roger_federer': 2,
#  'serena_williams': 3,
#  'virat_kohli': 4}

# %% [markdown]
# ## Save the trained model

# %%
# !pip install joblib
import joblib

joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\dell\anaconda3\envs\anaconda\lib\site-packages (1.3.2)
# ['saved_model.pkl']

# %% [markdown]
# ## Save Class Dictionary

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
